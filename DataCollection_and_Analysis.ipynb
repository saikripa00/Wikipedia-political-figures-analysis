# %% [markdown]
# # Article Page Info MediaWiki API Example
# This example illustrates how to access page info data using the [MediaWiki REST API for the EN Wikipedia](https://www.mediawiki.org/wiki/API:Main_page). This example shows how to request summary 'page info' for a single article page. The API documentation, [API:Info](https://www.mediawiki.org/wiki/API:Info), covers additional details that may be helpful when trying to use or understand this example.
#
# ## License
# This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.2 - September 16, 2024

# %%
# These are standard python modules
import json, time, urllib.parse
#
# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import requests
import pandas as pd

# %% [markdown]
# ## Data Collection
# Below is the section where the Wikimedia API is used to collect the page info data

# %%
#########
#
#    CONSTANTS
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"
API_HEADER_AGENT = 'User-Agent'

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': 'netid@uw.edu, University of Washington, MSDS DATA 512 - AUTUMN 2024'
}

df = pd.read_csv("politicians_by_country_AUG.2024.csv")

# Extract values from the 'name' column and convert them into a list
ARTICLE_TITLES = df['name'].tolist()
# ARTICLE_TITLES = [ 'Bison', 'Northern flicker', 'Red squirrel', 'Chinook salmon', 'Horseshoe bat' ]

# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included. If you don't want any this can simply be the empty string
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"
#PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageinfo_per_article(article_title = None,
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT,
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):

    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['titles'] = article_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    if API_HEADER_AGENT not in headers:
        raise Exception(f"The header data should include a '{API_HEADER_AGENT}' field that contains your UW email address.")

    if 'uwnetid@uw' in headers[API_HEADER_AGENT]:
        raise Exception(f"Use your UW email address in the '{API_HEADER_AGENT}' field.")

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# Here, I am collection the API response for multiple politician's name in a single request.

# %%
all_responses = {}
batch_size = 50
for i in range(0, len(df), batch_size):
    names = '|'.join(df['name'][i:i+batch_size])
    info = request_pageinfo_per_article(names)
    if 'query' in info and 'pages' in info['query']:
        response = info['query']['pages']
        for page_id in response:
            name = response[page_id]['title']
            all_responses[name] = response[page_id]

# %% [markdown]
# The collected api response is stored in the all_pageinfo_responses.json file

# %%
output_file = 'all_pageinfo_responses.json'

# Save the all_responses dictionary to a JSON file
with open(output_file, 'w') as f:
    json.dump(all_responses, f, indent=4)

# %%
len(list(all_responses.keys()))
# Out:
# 7111

# %% [markdown]
# In the section below, I will be using the page info response to get the politician names and in turn use another ORES API to get the liftwing article information.

# %% [markdown]
# # Requesting ORES scores through LiftWing ML Service API
# Wikimedia Foundation (WMF) is reworking access to their APIs. It is likely in the coming years that all API access will require some kind of authentication, either through a simple key/token or through some version of OAuth. For now this is still a work in progress. You can follow the progress from their [API portal](https://api.wikimedia.org/wiki/Main_Page). Another on-going change is better control over API services in situations where those services require additional computational resources, beyond simply serving the text of a web page (i.e., the text of an article). Services like ORES that require running an ML model over the text of an article page is an example of a compute intensive API service.
#
# Wikimedia is implementing a new Machine Learning (ML) service infrastructure that they call [LiftWing](https://wikitech.wikimedia.org/wiki/Machine_Learning/LiftWing). Given that ORES already has several ML models that have been well used, ORES is the first set of APIs that are being moved to LiftWing.
#
# This example illustrates how to generate article quality estimates for article revisions using the LiftWing version of [ORES](https://www.mediawiki.org/wiki/ORES). The [ORES API documentation](https://ores.wikimedia.org) can be accessed from the main ORES page. The [ORES LiftWing documentation](https://wikitech.wikimedia.org/wiki/Machine_Learning/LiftWing/Usage) is very thin ... even thinner than the standard ORES documentation. Further, it is clear that some parameters have been renamed (e.g., "revid" in the old ORES API is now "rev_id" in the LiftWing ORES API).
#
#
# ## License
# This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.0 - August 15, 2023

# %%
#########
#
#    CONSTANTS
#

#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = ((60.0*60.0)/5000.0)-API_LATENCY_ASSUMED  # The key authorizes 5000 requests per hour

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there
#
#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too
#
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "netid@uw.edu, University of Washington, MSDS DATA 512 - AUTUMN 2024",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}
#
#    This is a template for the parameters that we need to supply in the headers of an API request
#
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : "",         # your email address should go here
    'access_token'  : ""          # the access token you create will need to go here
}

#
#    A dictionary of English Wikipedia article titles (keys) and sample revision IDs that can be used for this ORES scoring example
#
ARTICLE_REVISIONS = { 'Bison':1085687913 , 'Northern flicker':1086582504 , 'Red squirrel':1083787665 , 'Chinook salmon':1085406228 , 'Horseshoe bat':1060601936 }

#
#    This is a template of the data required as a payload when making a scoring request of the ORES model
#
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

#
#    These are used later - defined here so they, at least, have empty values
#
USERNAME = ""
ACCESS_TOKEN = ""
#

# %% [markdown]
# ## Define a function to make the ORES API request
#
# The API request will be made using a function to encapsulate call and make access reusable in other notebooks. The procedure is parameterized, relying on the constants above for some important default parameters. The primary assumption is that this function will be used to request data for a set of article revisions. The main parameter is 'article_revid'. One should be able to simply pass in a new article revision id on each call and get back a python dictionary as the result. A valid result will be a dictionary that contains the probabilities that the specific revision is one of six different article quality levels. Generally, quality level with the highest probability score is considered the quality level for the article. This can be tricky when you have two (or more) highly probable quality levels.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT,
                                   model_name = API_ORES_EN_QUALITY_MODEL,
                                   request_data = ORES_REQUEST_DATA_TEMPLATE,
                                   header_format = REQUEST_HEADER_TEMPLATE,
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):

    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token

    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")

    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)

    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        headers[str(key)] = header_format[key].format(**header_params)

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free data
        # source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        #response = requests.get(request_url, headers=headers)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
with open('all_pageinfo_responses.json', 'r') as file:
    data = json.load(file)

# Convert JSON data to a dataframe
rev_df = pd.DataFrame.from_dict(data, orient='index')

# Adding a "name" column based on the dictionary keys
rev_df['name'] = rev_df.index

# Resetting the index so the "name" column is a regular column in the dataframe
rev_df.reset_index(drop=True, inplace=True)

rev_df['pageid'] = rev_df['pageid'].fillna(0).astype(int)
rev_df['lastrevid'] = rev_df['lastrevid'].fillna(0).astype(int)
rev_df['talkid'] = rev_df['talkid'].fillna(0).astype(int)
rev_df['length'] = rev_df['length'].fillna(0).astype(int)

# Reordering columns to have 'name' as the first column
rev_df = rev_df[['name'] + [col for col in rev_df.columns if col != 'name']]

# %%
# Check for NaNs, empty strings, or spaces in a column (for example: 'lastrevid')
# 1. Check for NaN values
has_nans = rev_df['lastrevid'].isna()

# 2. Check for empty strings or strings with only spaces
has_empty_spaces = rev_df['lastrevid'].apply(lambda x: isinstance(x, str) and x.strip() == '')

# Combine both checks
invalid_entries = has_nans | has_empty_spaces

# Display rows that contain NaNs, spaces, or empty strings
print("Rows with NaNs, spaces, or empty strings in 'lastrevid':")
print(rev_df[invalid_entries])
# Out:
# Rows with NaNs, spaces, or empty strings in 'lastrevid':
# Empty DataFrame
# Columns: [name, pageid, ns, title, contentmodel, pagelanguage, pagelanguagehtmlcode, pagelanguagedir, touched, lastrevid, length, talkid, fullurl, editurl, canonicalurl, watchers, missing, redirect, new]
# Index: []

# %%
# code to check if api response works
sample_row = rev_df.iloc[0]  # Get the first row of the DataFrame
name = sample_row['name']
lastrevid = (sample_row['lastrevid'])


# Example request data and header templates (fill in with your actual templates)
request_data = {"rev_id": None}  # Template for request data
header_format = {"Authorization": "Bearer {access_token}", "From": "{email_address}"}  # Example header format
header_params = {"email_address": "smohan5@uw.edu", "access_token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....uRRcC9Njy8DWcjVdSx1VoLqaZVUD2t1xUbNSr-8IT5SarTeLimSH_Q17JceJrp9HhRe-weXfHV6tW_pInV6jsmvYTNm2VgkCF6hqelRAufgyMwAnIRXjkXTda_s24awrn94_lPjN00B5g4mTd42VB_obysPR0RIMjC1apyIwQDIRbSw7uFEMoMPlx4VgSJH9cHd2HBn91arsyY5uWSpzvmkj0XIsSYR4fxoF4eFRV5mCWcfvV0F-mhC-yCy05uXu0ti9TjFKkuzsnNi81c27j9RvpKjBkbq_MSaHEDAoPSYUsktDRc0SOp6XycYpT0ZXIqGhCsonEFpKLXfDGkGbGtPr7bgOQA8_Q1zF_QhUiSrSm2Q38JtiPHwrv5UuJKLYqtfaKe58KXkrd2XkfE5GWe64jqbMA48lFZXH7c6EZEcd8JUoauxKS4o-yreSEqZUxofnfgXnm-gmhX5f3YJYgaKEhJnK-w0DzF5bofLTM3aH5-yuewQcK77HOZH4k8NZX4f1oWu1UW-r2PrMQdxEF8nDcsMtSl1eYEnhash23ddq1YDw6oOnDieaiGLf73uyX_gcYa9Bjs8kRttvYu-DSQwHIPCYKtFtZEsBuOdj6g6d9axw0fKKoEcweQtNABF4JkNMl6CzXkLm34o9QBUEaqzYBSUcTOVV7tobR3P1SGI"}  # Fill with your details
# Make the API call for the sample revision ID
response = request_ores_score_per_article(
    article_revid=int(lastrevid),  # Ensure it's an integer
    email_address=header_params['email_address'],
    access_token=header_params['access_token'],
    request_data=request_data,
    header_format=header_format,
    header_params=header_params
)

# Print the response for the sample row
print(f"Response for {name} (rev_id: {lastrevid}): {response}")
# Out:
# Response for Abdul Baqi Turkistani (rev_id: 1231655023): {'enwiki': {'models': {'articlequality': {'version': '0.9.2'}}, 'scores': {'1231655023': {'articlequality': {'score': {'prediction': 'Stub', 'probability': {'B': 0.007563164541978764, 'C': 0.010571998067933679, 'FA': 0.0014567448768872152, 'GA': 0.00350824677167893, 'Start': 0.04243220742433865, 'Stub': 0.9344676383171826}}}}}}}

# %%
import json

api_responses = {}
failed_revids = []  # List to store revids that encounter errors

# Iterate over the DataFrame and make API requests
for index, row in rev_df.iterrows():
    name = row['name']
    lastrevid = row['lastrevid']

    # Example request data and header templates (fill in with your actual templates)
    print('Fetching for: ', lastrevid)
    request_data = {"rev_id": lastrevid}
    header_format = {"Authorization": "Bearer {access_token}", "From": "{email_address}"}  # Example header format
    header_params = {
        "email_address": "smohan5@uw.edu",
        "access_token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....uRRcC9Njy8DWcjVdSx1VoLqaZVUD2t1xUbNSr-8IT5SarTeLimSH_Q17JceJrp9HhRe-weXfHV6tW_pInV6jsmvYTNm2VgkCF6hqelRAufgyMwAnIRXjkXTda_s24awrn94_lPjN00B5g4mTd42VB_obysPR0RIMjC1apyIwQDIRbSw7uFEMoMPlx4VgSJH9cHd2HBn91arsyY5uWSpzvmkj0XIsSYR4fxoF4eFRV5mCWcfvV0F-mhC-yCy05uXu0ti9TjFKkuzsnNi81c27j9RvpKjBkbq_MSaHEDAoPSYUsktDRc0SOp6XycYpT0ZXIqGhCsonEFpKLXfDGkGbGtPr7bgOQA8_Q1zF_QhUiSrSm2Q38JtiPHwrv5UuJKLYqtfaKe58KXkrd2XkfE5GWe64jqbMA48lFZXH7c6EZEcd8JUoauxKS4o-yreSEqZUxofnfgXnm-gmhX5f3YJYgaKEhJnK-w0DzF5bofLTM3aH5-yuewQcK77HOZH4k8NZX4f1oWu1UW-r2PrMQdxEF8nDcsMtSl1eYEnhash23ddq1YDw6oOnDieaiGLf73uyX_gcYa9Bjs8kRttvYu-DSQwHIPCYKtFtZEsBuOdj6g6d9axw0fKKoEcweQtNABF4JkNMl6CzXkLm34o9QBUEaqzYBSUcTOVV7tobR3P1SGI"  # Replace with your actual access token
    }

    try:
        # Make the API call
        response = request_ores_score_per_article(
            article_revid=lastrevid,
            email_address=header_params['email_address'],
            access_token=header_params['access_token'],
            request_data=request_data,
            header_format=header_format,
            header_params=header_params
        )

        # Store the response in the dictionary with lastrevid as the key
        if response:
            api_responses[lastrevid] = response
        else:
            api_responses[lastrevid] = None
            print(f"No response for {name} (rev_id: {lastrevid})")

    except Exception as e:
        # If there's an error, store the revid in the failed_revids list
        print(f"Error fetching data for {name} (rev_id: {lastrevid}): {e}")
        failed_revids.append(lastrevid)

    # Save the API responses periodically to avoid data loss in case of long runtime
    if index % 100 == 0:  # Adjust frequency as needed
        with open('ores_responses_partial.json', 'w') as json_file:
            json.dump(api_responses, json_file, indent=4)

# Save the final API responses as a JSON file
with open('ores_responses.json', 'w') as json_file:
    json.dump(api_responses, json_file, indent=4)

print(f"Failed revids: {failed_revids}")
# Out:
# Fetching for:  1231655023
# Fetching for:  1227026187
# Fetching for:  1226326055
# Fetching for:  1221720658
# Fetching for:  1185105938
# Fetching for:  1247931713
# Fetching for:  1195651393
# Fetching for:  1247762293
# Fetching for:  1176481824
# Fetching for:  1248505877
# Fetching for:  1193992206
# Fetching for:  1158302291
# Fetching for:  1234514379
# Fetching for:  1212323536
# Fetching for:  1158659195
# Fetching for:  1240993642
# Fetching for:  1238402857
# Fetching for:  1230459615
# Fetching for:  1207743719
# Fetching for:  1244521219
# Fetching for:  1227635806
# Fetching for:  1234741562
# Fetching for:  1243745950
# Fetching for:  1233202991
# Fetching for:  1246566971
# Fetching for:  1235165845
# Fetching for:  1246567093
# Fetching for:  1227103354
# Fetching for:  1237694188
# Fetching for:  1136611354
# Fetching for:  1247727443
# Fetching for:  1176429234
# Fetching for:  1134129082
# Fetching for:  949986748
# Fetching for:  1235521766
# Fetching for:  1246566804
# Fetching for:  988838315
# Fetching for:  1225385278
# Fetching for:  1246566795
# Fetching for:  1197443408
# Fetching for:  1234743111
# Fetching for:  1227180106
# Fetching for:  1248976824
# Fetching for:  1195409073
# Fetching for:  1137130537
# Fetching for:  1136614743
# Fetching for:  1234514565
# Fetching for:  1179137138
# Fetching for:  1245967190
# Fetching for:  1225661708
# Fetching for:  1136614520
# Fetching for:  1235405154
# Fetching for:  1225425205
# Fetching for:  1243758857
# Fetching for:  1145249317
# Fetching for:  1126667481
# Fetching for:  1171042170
# Fetching for:  1136630194
# Fetching for:  1244421894
# Fetching for:  1192928746
# Fetching for:  1236603169
# Fetching for:  1250227174
# Fetching for:  1217284690
# Fetching for:  1247131367
# Fetching for:  1239319380
# Fetching for:  1242412237
# Fetching for:  1136534788
# Fetching for:  1136614778
# Fetching for:  1176507815
# Fetching for:  1129192917
# Fetching for:  1136614561
# Fetching for:  1123824802
# Fetching for:  1136614726
# Fetching for:  1198914812
# Fetching for:  1248264998
# Fetching for:  1244463139
# Fetching for:  1250227994
# Fetching for:  1233490009
# Fetching for:  1178097642
# Fetching for:  1185088733
# Fetching for:  1229734414
# Fetching for:  1225457074
# Fetching for:  1136630129
# Fetching for:  1184807608
# Fetching for:  1209346411
# Fetching for:  1227179979
# Fetching for:  1245217124
# Fetching for:  1222381064
# Fetching for:  1227951669
# Fetching for:  1189442848
# Fetching for:  1204109653
# Fetching for:  1172646418
# Fetching for:  1224650124
# Fetching for:  1198363158
# Fetching for:  1196422551
# Fetching for:  1232389768
# Fetching for:  1221605713
# Fetching for:  1136614682
# Fetching for:  1223903677
# Fetching for:  1150044800
# Fetching for:  1240801210
# Fetching for:  1244008227
# Fetching for:  1196135017
# Fetching for:  1241836925
# Fetching for:  1209165678
# Fetching for:  1098236555
# Fetching for:  1227369252
# Fetching for:  1243882903
# Fetching for:  1112281132
# Fetching for:  1220369492
# Fetching for:  1229276965
# Fetching for:  1229938943
# Fetching for:  1237006808
# Fetching for:  1220757655
# Fetching for:  1180949734
# Fetching for:  1222151681
# Fetching for:  1141930406
# Fetching for:  1173107489
# Fetching for:  1174010569
# Fetching for:  1236738861
# Fetching for:  1227760361
# Fetching for:  1245450388
# Fetching for:  1218412314
# Fetching for:  1235824719
# Fetching for:  1228151428
# Fetching for:  1198167947
# Fetching for:  1237950375
# Fetching for:  1236739222
# Fetching for:  1244486529
# Fetching for:  1145510350
# Fetching for:  1239924043
# Fetching for:  1226635783
# Fetching for:  1235824584
# Fetching for:  1198219291
# Fetching for:  1244486537
# Fetching for:  1236738502
# Fetching for:  1198224146
# Fetching for:  1180949327
# Fetching for:  1180950488
# Fetching for:  1230739582
# Fetching for:  1240539074
# Fetching for:  1186986269
# Fetching for:  1234673487
# Fetching for:  1241037317
# Fetching for:  1180949774
# Fetching for:  1180950536
# Fetching for:  1209148780
# Fetching for:  1217259369
# Fetching for:  1240443327
# Fetching for:  1215667416
# Fetching for:  1218173615
# Fetching for:  1250270534
# Fetching for:  1245801726
# Fetching for:  1220757834
# Fetching for:  1203569345
# Fetching for:  1220281072
# Fetching for:  1176411375
# Fetching for:  1212186965
# Fetching for:  1226452639
# Fetching for:  1214835889
# Fetching for:  1219685755
# Fetching for:  1192088820
# Fetching for:  1237478919
# Fetching for:  1226437538
# Fetching for:  1053460621
# Fetching for:  1172500304
# Fetching for:  1234096174
# Fetching for:  1218302579
# Fetching for:  1217131488
# Fetching for:  1244337610
# Fetching for:  1242037866
# Fetching for:  1248318178
# Fetching for:  1242619010
# Fetching for:  1230623499
# Fetching for:  1214832676
# Fetching for:  1249963763
# Fetching for:  1111537825
# Fetching for:  1235824554
# Fetching for:  1169278443
# Fetching for:  1235672021
# Fetching for:  1224118485
# Fetching for:  1226553342
# Fetching for:  1226280389
# Fetching for:  1241671793
# Fetching for:  1227200392
# Fetching for:  1226271746
# Fetching for:  1213342432
# Fetching for:  1099284595
# Fetching for:  1232492563
# Fetching for:  1186319378
# Fetching for:  1240883461
# Fetching for:  1230435685
# Fetching for:  1134649751
# Fetching for:  1213344636
# Fetching for:  1248230838
# Fetching for:  1135323365
# Fetching for:  1143896123
# Fetching for:  1186319308
# Fetching for:  1239235131
# Fetching for:  1214834266
# Fetching for:  1218004839
# Fetching for:  1212579707
# Fetching for:  1218530483
# Fetching for:  1165626565
# Fetching for:  1124441544
# Fetching for:  1244123151
# Fetching for:  1242000475
# Fetching for:  1209524394
# Fetching for:  1213778323
# Fetching for:  1172178750
# Fetching for:  1235394946
# Fetching for:  1226279231
# Fetching for:  1209514022
# Fetching for:  1177486404
# Fetching for:  1233387309
# Fetching for:  1186318318
# Fetching for:  1210193481
# Fetching for:  1244511083
# Fetching for:  1241977204
# Fetching for:  1053461144
# Fetching for:  1209522689
# Fetching for:  1209514085
# Fetching for:  1217387083
# Fetching for:  1212186286
# Fetching for:  1220287872
# Fetching for:  1209631313
# Fetching for:  1242307432
# Fetching for:  1242307441
# Fetching for:  1242307337
# Fetching for:  1227794006
# Fetching for:  1191431794
# Fetching for:  1093124425
# Fetching for:  1215901775
# Fetching for:  1213795388
# Fetching for:  1213794210
# Fetching for:  1248662394
# Fetching for:  1186317568
# Fetching for:  1226060720
# Fetching for:  1213870570
# Fetching for:  1053469610
# Fetching for:  1213404244
# Fetching for:  1242307496
# Fetching for:  1158035855
# Fetching for:  1229426851
# Fetching for:  1212181372
# Fetching for:  1181986973
# Fetching for:  1226335614
# Fetching for:  1214837789
# Fetching for:  1214841607
# Fetching for:  1194150567
# Fetching for:  1247631794
# Fetching for:  1227909121
# Fetching for:  1219179734
# Fetching for:  1142474441
# Fetching for:  1241563135
# Fetching for:  1242813942
# Fetching for:  1241563106
# Fetching for:  1241563118
# Fetching for:  1187961349
# Fetching for:  1024544204
# Fetching for:  1220287990
# Fetching for:  1241977176
# Fetching for:  1242307454
# Fetching for:  1241563122
# Fetching for:  1242152285
# Fetching for:  1242307359
# Fetching for:  1246026420
# Fetching for:  1242307479
# Fetching for:  1228399791
# Fetching for:  1242841039
# Fetching for:  1154991360
# Fetching for:  1227004140
# Fetching for:  1153488959
# Fetching for:  1226309621
# Fetching for:  1240720719
# Fetching for:  1242306989
# Fetching for:  1247632329
# Fetching for:  1233607984
# Fetching for:  1209411144
# Fetching for:  1209411217
# Fetching for:  1250493481
# Fetching for:  1209413818
# Fetching for:  1218506469
# Fetching for:  1209513699
# Fetching for:  1243272129
# Fetching for:  1241563130
# Fetching for:  1209410923
# Fetching for:  1209539718
# Fetching for:  1115715527
# Fetching for:  1118804168
# Fetching for:  1247631912
# Fetching for:  1213836084
# Fetching for:  1246271741
# Fetching for:  1165626399
# Fetching for:  1242306726
# Fetching for:  1241563138
# Fetching for:  825090349
# Fetching for:  1227026341
# Fetching for:  1246340247
# Fetching for:  1250666577
# Fetching for:  1166331326
# Fetching for:  1231276700
# Fetching for:  1241592542
# Fetching for:  1225811362
# Fetching for:  1243926512
# Fetching for:  1241564686
# Fetching for:  1227620960
# Fetching for:  1209668330
# Fetching for:  1247632248
# Fetching for:  1247631631
# Fetching for:  1245130520
# Fetching for:  1248648606
# Fetching for:  1188044851
# Fetching for:  1247632282
# Fetching for:  1162056054
# Fetching for:  1223272051
# Fetching for:  1245178482
# Fetching for:  1241564680
# Fetching for:  1250713562
# Fetching for:  1067754685
# Fetching for:  1241592215
# Fetching for:  1241592526
# Fetching for:  1229623675
# Fetching for:  1227458965
# Fetching for:  1241563151
# Fetching for:  1227459720
# Fetching for:  1217815148
# Fetching for:  1227499891
# Fetching for:  1225784914
# Fetching for:  1148828249
# Fetching for:  1225793565
# Fetching for:  1241592202
# Fetching for:  1247632301
# Fetching for:  1247514093
# Fetching for:  1225793589
# Fetching for:  1234469779
# Fetching for:  1232135530
# Fetching for:  1227616001
# Fetching for:  1233010330
# Fetching for:  1135193654
# Fetching for:  1227515965
# Fetching for:  1241592535
# Fetching for:  1243279888
# Fetching for:  1247632342
# Fetching for:  1247632346
# Fetching for:  1227517224
# Fetching for:  1039135531
# Fetching for:  1247632364
# Fetching for:  1225775647
# Fetching for:  1217815124
# Fetching for:  1245068036
# Fetching for:  1106856167
# Fetching for:  1138003698
# Fetching for:  1226445117
# Fetching for:  1226040049
# Fetching for:  1214660728
# Fetching for:  1248572448
# Fetching for:  1214660921
# Fetching for:  1214661551
# Fetching for:  1227361697
# Fetching for:  1218601969
# Fetching for:  1225799546
# Fetching for:  1199679676
# Fetching for:  1245464700
# Fetching for:  1016343362
# Fetching for:  1217866134
# Fetching for:  1238199017
# Fetching for:  1180063729
# Fetching for:  1180063778
# Fetching for:  1096175549
# Fetching for:  1103745376
# Fetching for:  1231768992
# Fetching for:  1250311867
# Fetching for:  1222501416
# Fetching for:  1191859791
# Fetching for:  1166892817
# Fetching for:  1195011460
# Fetching for:  1234698824
# Fetching for:  1210493386
# Fetching for:  1210433646
# Fetching for:  1242262794
# Fetching for:  1248788227
# Fetching for:  1247590161
# Fetching for:  1166890663
# Fetching for:  1211044406
# Fetching for:  1226313476
# Fetching for:  797826672
# Fetching for:  1222899462
# Fetching for:  1225799869
# Fetching for:  1214660598
# Fetching for:  1240898573
# Fetching for:  1228290809
# Fetching for:  1214661775
# Fetching for:  1193099129
# Fetching for:  1228141029
# Fetching for:  1231946069
# Fetching for:  1237979345
# Fetching for:  1224369324
# Fetching for:  1214661649
# Fetching for:  1124301399
# Fetching for:  1244617588
# Fetching for:  1215046038
# Fetching for:  1215044432
# Fetching for:  1214662146
# Fetching for:  1200893975
# Fetching for:  1214682376
# Fetching for:  1215043825
# Fetching for:  1216075327
# Fetching for:  1232067132
# Fetching for:  1244619292
# Fetching for:  1214236945
# Fetching for:  1223497595
# Fetching for:  1215043658
# Fetching for:  1240224564
# Fetching for:  1249622641
# Fetching for:  1214662694
# Fetching for:  1231555745
# Fetching for:  1240489075
# Fetching for:  1226351964
# Fetching for:  1214670404
# Fetching for:  1215044008
# Fetching for:  1243511026
# Fetching for:  1225140706
# Fetching for:  1244447844
# Fetching for:  1243510830
# Fetching for:  1214986895
# Fetching for:  1214670744
# Fetching for:  1169137921
# Fetching for:  1215045853
# Fetching for:  1217803359
# Fetching for:  1214670011
# Fetching for:  1242771327
# Fetching for:  1228353209
# Fetching for:  1214669503
# Fetching for:  1226152632
# Fetching for:  1106829544
# Fetching for:  1233470777
# Fetching for:  1215201883
# Fetching for:  1215924661
# Fetching for:  1237091760
# Fetching for:  1243336388
# Fetching for:  1222543352
# Fetching for:  1242552103
# Fetching for:  1242146414
# Fetching for:  1215046740
# Fetching for:  1216088776
# Fetching for:  1243494457
# Fetching for:  1214669611
# Fetching for:  1154443829
# Fetching for:  1215187552
# Fetching for:  1211047878
# Fetching for:  1231556425
# Fetching for:  1215184008
# Fetching for:  1215054758
# Fetching for:  1243965585
# Fetching for:  1236388140
# Fetching for:  1243626881
# Fetching for:  1215483185
# Fetching for:  1215185845
# Fetching for:  1161577254
# Fetching for:  1250642641
# Fetching for:  1250188481
# Fetching for:  1215054152
# Fetching for:  1228417930
# Fetching for:  1215186237
# Fetching for:  1238011369
# Fetching for:  1215187415
# Fetching for:  1235730032
# Fetching for:  1236098636
# Fetching for:  1246777408
# Fetching for:  1246630894
# Fetching for:  1226214871
# Fetching for:  1215185628
# Fetching for:  1242810704
# Fetching for:  1248404055
# Fetching for:  1226209962
# Fetching for:  1215186443
# Fetching for:  1248432097
# Fetching for:  1153989705
# Fetching for:  1215053905
# Fetching for:  1215054486
# Fetching for:  1231556362
# Fetching for:  1231556108
# Fetching for:  1215186109
# Fetching for:  1240906258
# Fetching for:  1215186791
# Fetching for:  1248552155
# Fetching for:  1230366514
# Fetching for:  1241392879
# Fetching for:  1223484511
# Fetching for:  1239601735
# Fetching for:  1240951343
# Fetching for:  1240127163
# Fetching for:  1099978355
# Fetching for:  1235856770
# Fetching for:  1240965677
# Fetching for:  1215185462
# Fetching for:  1249288737
# Fetching for:  1242446030
# Fetching for:  1241052691
# Fetching for:  1243747432
# Fetching for:  1187254621
# Fetching for:  1157124148
# Fetching for:  1247420701
# Fetching for:  1237483914
# Fetching for:  1245270394
# Fetching for:  1244157806
# Fetching for:  1245282668
# Fetching for:  1246588423
# Fetching for:  1207738330
# Fetching for:  1245270299
# Fetching for:  1147579900
# Fetching for:  1246060446
# Fetching for:  1235219197
# Fetching for:  1213943020
# Fetching for:  1246060690
# Fetching for:  1217681945
# Fetching for:  1245503366
# Fetching for:  1246286594
# Fetching for:  1243509483
# Fetching for:  1246060699
# Fetching for:  1234004989
# Fetching for:  1243520102
# Fetching for:  1239189558
# Fetching for:  1244589428
# Fetching for:  1236490430
# Fetching for:  1199215674
# Fetching for:  1011331249
# Fetching for:  1225308278
# Fetching for:  1248447237
# Fetching for:  1228687346
# Fetching for:  1226230854
# Fetching for:  1248225337
# Fetching for:  1243510539
# Fetching for:  1244201378
# Fetching for:  1237445893
# Fetching for:  1226415908
# Fetching for:  1236490449
# Fetching for:  1243510550
# Fetching for:  1248662299
# Fetching for:  1250266366
# Fetching for:  1222623261
# Fetching for:  1207600921
# Fetching for:  1067081975
# Fetching for:  1232296078
# Fetching for:  1249203876
# Fetching for:  1208072134
# Fetching for:  1224596001
# Fetching for:  1223700072
# Fetching for:  1182830303
# Fetching for:  1243510547
# Fetching for:  1063482737
# Fetching for:  1231654401
# Fetching for:  1227286508
# Fetching for:  1249675761
# Fetching for:  1162793449
# Fetching for:  1206211739
# Fetching for:  1194162044
# Fetching for:  1181612386
# Fetching for:  1218302538
# Fetching for:  1248662296
# Fetching for:  1142294843
# Fetching for:  1148385245
# Fetching for:  1198202282
# Fetching for:  1106104383
# Fetching for:  1243510572
# Fetching for:  1098344827
# Fetching for:  1146485875
# Fetching for:  1148959062
# Fetching for:  1248344476
# Fetching for:  1177286981
# Fetching for:  1177467150
# Fetching for:  1215486840
# Fetching for:  1243023554
# Fetching for:  1215466172
# Fetching for:  1161492589
# Fetching for:  1185599926
# Fetching for:  1238577650
# Fetching for:  1006173162
# Fetching for:  1171757402
# Fetching for:  1241255046
# Fetching for:  1159628135
# Fetching for:  1158375491
# Fetching for:  1241906132
# Fetching for:  1243510541
# Fetching for:  1226025677
# Fetching for:  1213858589
# Fetching for:  1099067663
# Fetching for:  1208078338
# Fetching for:  1245157534
# Fetching for:  1213002608
# Fetching for:  1243520070
# Fetching for:  1193027962
# Fetching for:  1210593900
# Fetching for:  1245586658
# Fetching for:  1208077047
# Fetching for:  1243510546
# Fetching for:  1213965350
# Fetching for:  1245380545
# Fetching for:  1246694478
# Fetching for:  1245374567
# Fetching for:  1195787872
# Fetching for:  1219928150
# Fetching for:  1241499929
# Fetching for:  1227285970
# Fetching for:  1235804624
# Fetching for:  1245374007
# Fetching for:  1232200030
# Fetching for:  1244755894
# Fetching for:  1221144846
# Fetching for:  1250715667
# Fetching for:  1239617504
# Fetching for:  1175807916
# Fetching for:  1245379837
# Fetching for:  1140605737
# Fetching for:  1245395466
# Fetching for:  1245380479
# Fetching for:  1246126702
# Fetching for:  1242147738
# Fetching for:  1237261756
# Fetching for:  1006167519
# Fetching for:  1172576081
# Fetching for:  1245375794
# Fetching for:  1232948277
# Fetching for:  1233118749
# Fetching for:  1156409493
# Fetching for:  1249444464
# Fetching for:  1209519423
# Fetching for:  1242815841
# Fetching for:  1217876419
# Fetching for:  1250294465
# Fetching for:  1245377984
# Fetching for:  1063213013
# Fetching for:  1244455253
# Fetching for:  1202322111
# Fetching for:  1166369458
# Fetching for:  1245380189
# Fetching for:  1236303322
# Fetching for:  1247061966
# Fetching for:  1247375502
# Fetching for:  1250494329
# Fetching for:  1247375519
# Fetching for:  1245377291
# Fetching for:  1098699647
# Fetching for:  1183475136
# Fetching for:  1245374148
# Fetching for:  1245379554
# Fetching for:  1228415190
# Fetching for:  1245402550
# Fetching for:  1237265302
# Fetching for:  1250599443
# Fetching for:  1246347372
# Fetching for:  1232782976
# Fetching for:  1245380771
# Fetching for:  1245374666
# Fetching for:  1220769997
# Fetching for:  1245376617
# Fetching for:  1240939624
# Fetching for:  1247376048
# Fetching for:  1242611945
# Fetching for:  1243563371
# Fetching for:  1246263516
# Fetching for:  1250709727
# Fetching for:  1245395381
# Fetching for:  1230176939
# Fetching for:  1237261567
# Fetching for:  1247693188
# Fetching for:  1212687396
# Fetching for:  1247242676
# Fetching for:  1237261507
# Fetching for:  1226325755
# Fetching for:  1242580877
# Fetching for:  1250491967
# Fetching for:  1117752666
# Fetching for:  1245961260
# Fetching for:  1067136662
# Fetching for:  1237264157
# Fetching for:  1046006361
# Fetching for:  1245374883
# Fetching for:  1245374542
# Fetching for:  1225060231
# Fetching for:  1249497016
# Fetching for:  1241208220
# Fetching for:  1245374586
# Fetching for:  1066093324
# Fetching for:  1245378724
# Fetching for:  1242126632
# Fetching for:  1242257552
# Fetching for:  1246459927
# Fetching for:  1245978368
# Fetching for:  1245374454
# Fetching for:  1232199873
# Fetching for:  1245374793
# Fetching for:  1247089625
# Fetching for:  1245394398
# Fetching for:  1247669907
# Fetching for:  1244156514
# Fetching for:  1237263822
# Fetching for:  1079840895
# Fetching for:  1173907794
# Fetching for:  1235204307
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5be940ff6853> in <cell line: 7>()
#      20     try:
#      21         # Make the API call
# ---> 22         response = request_ores_score_per_article(
#      23             article_revid=lastrevid,
#      24             email_address=header_params['email_address'],
#
# <ipython-input-4-244e0d7cc526> in request_ores_score_per_article(article_revid, email_address, access_token, endpoint_url, model_name, request_data, header_format, header_params)
#      42         # source like ORES - or other community sources
#      43         if API_THROTTLE_WAIT > 0.0:
# ---> 44             time.sleep(API_THROTTLE_WAIT)
#      45         #response = requests.get(request_url, headers=headers)
#      46         response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
#
# KeyboardInterrupt:

# %% [markdown]
# Now, the article information and scores data is stored in the ORES response json file. Below I will be reading that file and converting it to a dataframe to further use them in the analysis

# %%
# code to read json and convert to df
with open('ores_responses(1).json', 'r') as file:
    data = json.load(file)

rows = []
for rev_id, rev_data in data.items():
    try:
        # Ensure the data for enwiki, scores, articlequality, and prediction exist and are not None
        if (
            rev_data
            and 'enwiki' in rev_data
            and 'scores' in rev_data['enwiki']
            and rev_id in rev_data['enwiki']['scores']
            and 'articlequality' in rev_data['enwiki']['scores'][rev_id]
            and 'score' in rev_data['enwiki']['scores'][rev_id]['articlequality']
            and 'prediction' in rev_data['enwiki']['scores'][rev_id]['articlequality']['score']
        ):
            article_quality = rev_data['enwiki']['scores'][rev_id]['articlequality']['score']['prediction']
            # Append the revision ID and article quality to the list
            rows.append({'revision_id': rev_id, 'article_quality': article_quality})
        else:
            print(f"Data missing for revision ID {rev_id}")
    except KeyError:
        print(f"KeyError for revision ID {rev_id}: some data is missing.")


article_df = pd.DataFrame(rows)
print(article_df)
# Out:
# Data missing for revision ID 1245373664
#      revision_id article_quality
# 0     1231655023            Stub
# 1     1227026187            Stub
# 2     1226326055           Start
# 3     1221720658           Start
# 4     1185105938            Stub
# ...          ...             ...
# 7097  1247902630               C
# 7098   959111842            Stub
# 7099  1203429435               C
# 7100  1246280093            Stub
# 7101  1228478288           Start
#
# [7102 rows x 2 columns]

# %% [markdown]
# Data missing for revision ID 1245373664

# %% [markdown]
# Your notebook should compute and print the score error rate. The error rate is the ratio of the number of articles for which you were not able to get a score divided by the total number of articles. If your request error rate is higher than 1%, then you should review your code, determine what is going wrong, fix it, and rerun your score collection.
#
# Next, I am checking if I got the scores for all the articles. Below I am calculating the request error rate.

# %%
# check if there's a result for all politican names.
# I am joining the page info dataframe with article info dataframe based on the revision id column
# Convert both 'lastrevid' and 'revision_id' columns to string type
rev_df['lastrevid'] = rev_df['lastrevid'].astype(str)
article_df['revision_id'] = article_df['revision_id'].astype(str)

# Use pd.merge() to join the two DataFrames on 'lastrevid' and 'revision_id'
merged_df = pd.merge(rev_df, article_df, left_on='lastrevid', right_on='revision_id', how='left')

# Replace missing values (NaN) in the merged DataFrame with empty strings
merged_df.fillna('', inplace=True)

missing_article_info = merged_df[merged_df['revision_id'] == '']

# Print the names of the politicians with missing article info
missing_politicians = missing_article_info['name'].tolist()

print("Politicians where article information is missing:")
for name in missing_politicians:
    print(name)

# Display the merged DataFrame
print(merged_df)
# Out:
# Politicians where article information is missing:
# Naw Susanna Hla Hla Soe
# Barbara Eibinger-Miedl
# Mehrali Gasimov
# Kyaw Myint
# André Ngongang Ouandji
# Tomás Pimentel
# Richard Sumah
# Segun ''Aeroland'' Adewale
# Bashir Bililiqo
#                             name    pageid  ns                       title  \
# 0          Abdul Baqi Turkistani  27428272   0       Abdul Baqi Turkistani
# 1              Abdul Ghani Ghani  29443640   0           Abdul Ghani Ghani
# 2             Abdul Rahim Ayoubi  44482763   0          Abdul Rahim Ayoubi
# 3             Ahmad Wali Massoud  34682634   0          Ahmad Wali Massoud
# 4                    Aimal Faizi  52438668   0                 Aimal Faizi
# ...                          ...       ...  ..                         ...
# 7106      André Ngongang Ouandji         0   0      André Ngongang Ouandji
# 7107              Tomás Pimentel         0   0              Tomás Pimentel
# 7108               Richard Sumah         0   0               Richard Sumah
# 7109  Segun ''Aeroland'' Adewale         0   0  Segun ''Aeroland'' Adewale
# 7110             Bashir Bililiqo         0   0             Bashir Bililiqo
#
#      contentmodel pagelanguage pagelanguagehtmlcode pagelanguagedir  \
# 0        wikitext           en                   en             ltr
# 1        wikitext           en                   en             ltr
# 2        wikitext           en                   en             ltr
# 3        wikitext           en                   en             ltr
# 4        wikitext           en                   en             ltr
# ...           ...          ...                  ...             ...
# 7106     wikitext           en                   en             ltr
# 7107     wikitext           en                   en             ltr
# 7108     wikitext           en                   en             ltr
# 7109     wikitext           en                   en             ltr
# 7110     wikitext           en                   en             ltr
#
#                    touched   lastrevid  ...    talkid  \
# 0     2024-09-27T01:07:35Z  1231655023  ...  27595416
# 1     2024-10-11T00:23:52Z  1227026187  ...  29453228
# 2     2024-10-11T16:51:32Z  1226326055  ...  44489967
# 3     2024-10-11T00:24:44Z  1221720658  ...  34682647
# 4     2024-10-11T00:27:38Z  1185105938  ...  52491442
# ...                    ...         ...  ...       ...
# 7106                                 0  ...         0
# 7107                                 0  ...         0
# 7108                                 0  ...         0
# 7109                                 0  ...         0
# 7110                                 0  ...         0
#
#                                                 fullurl  \
# 0     https://en.wikipedia.org/wiki/Abdul_Baqi_Turki...
# 1       https://en.wikipedia.org/wiki/Abdul_Ghani_Ghani
# 2      https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi
# 3      https://en.wikipedia.org/wiki/Ahmad_Wali_Massoud
# 4             https://en.wikipedia.org/wiki/Aimal_Faizi
# ...                                                 ...
# 7106  https://en.wikipedia.org/wiki/Andr%C3%A9_Ngong...
# 7107  https://en.wikipedia.org/wiki/Tom%C3%A1s_Pimentel
# 7108        https://en.wikipedia.org/wiki/Richard_Sumah
# 7109  https://en.wikipedia.org/wiki/Segun_%27%27Aero...
# 7110      https://en.wikipedia.org/wiki/Bashir_Bililiqo
#
#                                                 editurl  \
# 0     https://en.wikipedia.org/w/index.php?title=Abd...
# 1     https://en.wikipedia.org/w/index.php?title=Abd...
# 2     https://en.wikipedia.org/w/index.php?title=Abd...
# 3     https://en.wikipedia.org/w/index.php?title=Ahm...
# 4     https://en.wikipedia.org/w/index.php?title=Aim...
# ...                                                 ...
# 7106  https://en.wikipedia.org/w/index.php?title=And...
# 7107  https://en.wikipedia.org/w/index.php?title=Tom...
# 7108  https://en.wikipedia.org/w/index.php?title=Ric...
# 7109  https://en.wikipedia.org/w/index.php?title=Seg...
# 7110  https://en.wikipedia.org/w/index.php?title=Bas...
#
#                                            canonicalurl watchers missing  \
# 0     https://en.wikipedia.org/wiki/Abdul_Baqi_Turki...
# 1       https://en.wikipedia.org/wiki/Abdul_Ghani_Ghani
# 2      https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi
# 3      https://en.wikipedia.org/wiki/Ahmad_Wali_Massoud
# 4             https://en.wikipedia.org/wiki/Aimal_Faizi
# ...                                                 ...      ...     ...
# 7106  https://en.wikipedia.org/wiki/Andr%C3%A9_Ngong...
# 7107  https://en.wikipedia.org/wiki/Tom%C3%A1s_Pimentel
# 7108        https://en.wikipedia.org/wiki/Richard_Sumah
# 7109  https://en.wikipedia.org/wiki/Segun_%27%27Aero...
# 7110      https://en.wikipedia.org/wiki/Bashir_Bililiqo
#
#      redirect new revision_id article_quality
# 0                  1231655023            Stub
# 1                  1227026187            Stub
# 2                  1226326055           Start
# 3                  1221720658           Start
# 4                  1185105938            Stub
# ...       ...  ..         ...             ...
# 7106
# 7107
# 7108
# 7109
# 7110
#
# [7111 rows x 21 columns]
# <ipython-input-15-aee280e81f94>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   merged_df.fillna('', inplace=True)

# %% [markdown]
# Politicians where article information is missing:
# Naw Susanna Hla Hla Soe
# Barbara Eibinger-Miedl
# Mehrali Gasimov
# Kyaw Myint
# André Ngongang Ouandji
# Tomás Pimentel
# Richard Sumah
# Segun ''Aeroland'' Adewale
# Bashir Bililiqo
#
# From this we can calculate the error rate.

# %%
Total_number_of_articles = 7102
number_of_missing = len(missing_politicians)
error_rate = number_of_missing/Total_number_of_articles
error_rate*100
# Out:
# 0.12672486623486343

# %% [markdown]
# Error rate = 0.126%
# Which is within the limit

# %% [markdown]
# Combining the datasets

# %%
# Now I need to merge the population by country csv with merged data

politicians_df = pd.read_csv('politicians_by_country_AUG.2024.csv')
population_df = pd.read_csv('population_by_country_AUG.2024.csv')

print(politicians_df.columns)
print(population_df.columns)

# merging these csvs
# Merging on 'country' from politicians_df and 'Geography' from population_df
#politicians_df = pd.merge(politicians_df, population_df, left_on='country', right_on='Geography', how='left')
#politicians_df.head()

# Merging the two DataFrames using an outer join
politicians_merged_df = pd.merge(
    politicians_df,
    population_df,
    left_on='country',
    right_on='Geography',
    how='outer'
)

# Optional: Fill NaN values with an empty string or any other value you prefer
politicians_merged_df.fillna('', inplace=True)

politicians_merged_df.head()
# Out:
# Index(['name', 'url', 'country'], dtype='object')
# Index(['Geography', 'Population'], dtype='object')
# <ipython-input-26-ce5f5a59af9c>:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   politicians_merged_df.fillna('', inplace=True)
#                 name                                              url  \
# 0
# 1
# 2     Majah Ha Adrif     https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 3  Haroon al-Afghani  https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 4        Tayyab Agha        https://en.wikipedia.org/wiki/Tayyab_Agha
#
#        country    Geography Population
# 0                    AFRICA     1453.0
# 1                      ASIA     4739.0
# 2  Afghanistan  Afghanistan       42.4
# 3  Afghanistan  Afghanistan       42.4
# 4  Afghanistan  Afghanistan       42.4

# %% [markdown]
# Combining all the dataframes together

# %%
# combining merged_df that has article data with country information based on the name column
# Merging the DataFrames using an outer join
combined_data = pd.merge(
    merged_df,
    politicians_merged_df,
    on='name',  # Use 'on' since both DataFrames have the same column name
    how='outer'  # Use 'outer' to retain all rows
)

# Display the first few rows of the combined DataFrame
combined_data.head()
# Out:
#   name  pageid  ns title contentmodel pagelanguage pagelanguagehtmlcode  \
# 0          NaN NaN   NaN          NaN          NaN                  NaN
# 1          NaN NaN   NaN          NaN          NaN                  NaN
# 2          NaN NaN   NaN          NaN          NaN                  NaN
# 3          NaN NaN   NaN          NaN          NaN                  NaN
# 4          NaN NaN   NaN          NaN          NaN                  NaN
#
#   pagelanguagedir touched lastrevid  ...  watchers  missing redirect  new  \
# 0             NaN     NaN       NaN  ...       NaN      NaN      NaN  NaN
# 1             NaN     NaN       NaN  ...       NaN      NaN      NaN  NaN
# 2             NaN     NaN       NaN  ...       NaN      NaN      NaN  NaN
# 3             NaN     NaN       NaN  ...       NaN      NaN      NaN  NaN
# 4             NaN     NaN       NaN  ...       NaN      NaN      NaN  NaN
#
#   revision_id article_quality url country  Geography Population
# 0         NaN             NaN                 AFRICA     1453.0
# 1         NaN             NaN                   ASIA     4739.0
# 2         NaN             NaN                Andorra        0.1
# 3         NaN             NaN              Australia       26.6
# 4         NaN             NaN                 Brunei        0.4
#
# [5 rows x 25 columns]

# %%
# Identify rows with no matches (NaN or empty string in 'name' column)
no_match_data = combined_data[combined_data['name'].isna() | (combined_data['name'] == '')]

# Extract the 'country' and 'Geography' columns
no_match_countries_geography = no_match_data[['country', 'Geography']]

# Write the output to a file
with open('wp_countries-no_match.txt', 'w') as file:
    for index, row in no_match_countries_geography.iterrows():
        country = row['country'] if pd.notna(row['country']) else ""
        geography = row['Geography'] if pd.notna(row['Geography']) else ""
        file.write(f"{country}, {geography}\n")

# Check if any countries with no matches were found
if no_match_data.empty:
    print("No countries with no matches found.")

# %%
# consolidating rest of the data
consolidated_data = combined_data[~(combined_data['name'].isna() | (combined_data['name'] == ''))]

# Select the specified columns for the final DataFrame
final_data = consolidated_data[['country', 'Geography', 'Population', 'title', 'revision_id', 'article_quality']].copy()

# Rename 'Geography' to 'region' and 'Population' to 'population' for clarity
final_data.rename(columns={
    'Geography': 'region',
    'Population': 'population',
    'title': 'article_title'
}, inplace=True)

# Save the final DataFrame to a CSV file
final_data.to_csv('wp_politicians_by_country.csv', index=False)

# %% [markdown]
# ## Analysis

# %%
high_quality = final_data[final_data["article_quality"].isin(["FA", "GA"])]

# Step 2: Calculate total articles and high-quality articles per country
total_articles_per_country = final_data.groupby("country").size().reset_index(name="total_articles")
high_quality_articles_per_country = high_quality.groupby("country").size().reset_index(name="high_quality_articles")

# Step 3: Merge the article counts with population data
merged = pd.merge(total_articles_per_country, high_quality_articles_per_country, on="country", how="left").fillna(0)
merged = pd.merge(merged, final_data[["country", "population", "region"]].drop_duplicates(), on="country", how="left")

# Convert population from millions to actual number
merged["population_actual"] = merged["population"] * 1_000_000

# step 4
# Convert the relevant columns to numeric types
merged["total_articles"] = pd.to_numeric(merged["total_articles"], errors='coerce')
merged["high_quality_articles"] = pd.to_numeric(merged["high_quality_articles"], errors='coerce')
merged["population_actual"] = pd.to_numeric(merged["population_actual"], errors='coerce')

# Perform the division again
merged["articles_per_capita"] = merged["total_articles"] / merged["population_actual"]
merged["high_quality_articles_per_capita"] = merged["high_quality_articles"] / merged["population_actual"]


# Step 5: Calculate regional aggregates
regional_aggregates = merged.groupby("region").agg(
    total_articles=("total_articles", "sum"),
    total_population=("population_actual", "sum"),
    high_quality_articles=("high_quality_articles", "sum")
).reset_index()

regional_aggregates["articles_per_capita"] = regional_aggregates["total_articles"] / regional_aggregates["total_population"]
regional_aggregates["high_quality_articles_per_capita"] = (
    regional_aggregates["high_quality_articles"] / regional_aggregates["total_population"]
)

# %%
filtered_merged = merged[merged["population_actual"] > 0]

# %%
top_10_coverage = filtered_merged.sort_values("articles_per_capita", ascending=False).head(10)
top_10_coverage
# Out:
#                             country  total_articles  high_quality_articles  \
# 4               Antigua and Barbuda              33                    0.0
# 51   Federated States of Micronesia              14                    0.0
# 96                 Marshall Islands              13                    0.0
# 152                           Tonga              10                    0.0
# 12                         Barbados              25                    0.0
# 128                      Seychelles               6                    0.0
# 101                      Montenegro              36                    3.0
# 17                           Bhutan              44                    0.0
# 93                         Maldives              33                    1.0
# 124                           Samoa               8                    0.0
#
#     population                          region  population_actual  \
# 4          0.1             Antigua and Barbuda           100000.0
# 51         0.1  Federated States of Micronesia           100000.0
# 96         0.1                Marshall Islands           100000.0
# 152        0.1                           Tonga           100000.0
# 12         0.3                        Barbados           300000.0
# 128        0.1                      Seychelles           100000.0
# 101        0.6                      Montenegro           600000.0
# 17         0.8                          Bhutan           800000.0
# 93         0.6                        Maldives           600000.0
# 124        0.2                           Samoa           200000.0
#
#      articles_per_capita  high_quality_articles_per_capita
# 4               0.000330                          0.000000
# 51              0.000140                          0.000000
# 96              0.000130                          0.000000
# 152             0.000100                          0.000000
# 12              0.000083                          0.000000
# 128             0.000060                          0.000000
# 101             0.000060                          0.000005
# 17              0.000055                          0.000000
# 93              0.000055                          0.000002
# 124             0.000040                          0.000000

# %%
# Bottom 10 countries by total articles per capita
bottom_10_coverage = filtered_merged.sort_values("articles_per_capita", ascending=True).head(10)
bottom_10_coverage
# Out:
#            country  total_articles  high_quality_articles population  \
# 31           China              16                    0.0     1411.3
# 67           India             151                    0.0     1428.6
# 57           Ghana               4                    1.0       34.1
# 125   Saudi Arabia               5                    2.0       36.9
# 167         Zambia               3                    0.0       20.2
# 111         Norway               1                    0.0        5.5
# 71          Israel               2                    0.0        9.8
# 45           Egypt              32                    1.0      105.2
# 37   Cote d'Ivoire              10                    0.0       30.9
# 50        Ethiopia              44                    2.0      126.5
#
#             region  population_actual  articles_per_capita  \
# 31           China       1.411300e+09         1.133707e-08
# 67           India       1.428600e+09         1.056979e-07
# 57           Ghana       3.410000e+07         1.173021e-07
# 125   Saudi Arabia       3.690000e+07         1.355014e-07
# 167         Zambia       2.020000e+07         1.485149e-07
# 111         Norway       5.500000e+06         1.818182e-07
# 71          Israel       9.800000e+06         2.040816e-07
# 45           Egypt       1.052000e+08         3.041825e-07
# 37   Cote d'Ivoire       3.090000e+07         3.236246e-07
# 50        Ethiopia       1.265000e+08         3.478261e-07
#
#      high_quality_articles_per_capita
# 31                       0.000000e+00
# 67                       0.000000e+00
# 57                       2.932551e-08
# 125                      5.420054e-08
# 167                      0.000000e+00
# 111                      0.000000e+00
# 71                       0.000000e+00
# 45                       9.505703e-09
# 37                       0.000000e+00
# 50                       1.581028e-08

# %%
# Top 10 countries by high-quality articles per capita
top_10_high_quality = filtered_merged.sort_values("high_quality_articles_per_capita", ascending=False).head(10)
top_10_high_quality
# Out:
#                    country  total_articles  high_quality_articles population  \
# 101             Montenegro              36                    3.0        0.6
# 89              Luxembourg              27                    2.0        0.7
# 1                  Albania              70                    7.0        2.7
# 79                  Kosovo              26                    4.0        1.7
# 93                Maldives              33                    1.0        0.6
# 88               Lithuania              58                    4.0        2.9
# 38                 Croatia              65                    5.0        3.8
# 63                  Guyana              17                    1.0        0.8
# 114  Palestinian Territory              61                    6.0        5.5
# 132               Slovenia              38                    2.0        2.1
#
#                     region  population_actual  articles_per_capita  \
# 101             Montenegro           600000.0             0.000060
# 89              Luxembourg           700000.0             0.000039
# 1                  Albania          2700000.0             0.000026
# 79                  Kosovo          1700000.0             0.000015
# 93                Maldives           600000.0             0.000055
# 88               Lithuania          2900000.0             0.000020
# 38                 Croatia          3800000.0             0.000017
# 63                  Guyana           800000.0             0.000021
# 114  Palestinian Territory          5500000.0             0.000011
# 132               Slovenia          2100000.0             0.000018
#
#      high_quality_articles_per_capita
# 101                      5.000000e-06
# 89                       2.857143e-06
# 1                        2.592593e-06
# 79                       2.352941e-06
# 93                       1.666667e-06
# 88                       1.379310e-06
# 38                       1.315789e-06
# 63                       1.250000e-06
# 114                      1.090909e-06
# 132                      9.523810e-07

# %%
# Bottom 10 countries by high-quality articles per capita
bottom_10_high_quality = filtered_merged.sort_values("high_quality_articles_per_capita", ascending=True).head(10)
bottom_10_high_quality
# Out:
#                  country  total_articles  high_quality_articles population  \
# 168             Zimbabwe              69                    0.0       16.7
# 34                 Congo              31                    0.0        6.1
# 80                Kuwait              17                    0.0        4.4
# 140            St. Lucia               3                    0.0        0.2
# 37         Cote d'Ivoire              10                    0.0       30.9
# 139  St. Kitts and Nevis               3                    0.0        0.1
# 133      Solomon Islands              12                    0.0        0.8
# 40                Cyprus              16                    0.0        1.3
# 130            Singapore               4                    0.0        5.8
# 42              Djibouti              15                    0.0        1.1
#
#                   region  population_actual  articles_per_capita  \
# 168             Zimbabwe         16700000.0         4.131737e-06
# 34                 Congo          6100000.0         5.081967e-06
# 80                Kuwait          4400000.0         3.863636e-06
# 140            St. Lucia           200000.0         1.500000e-05
# 37         Cote d'Ivoire         30900000.0         3.236246e-07
# 139  St. Kitts and Nevis           100000.0         3.000000e-05
# 133      Solomon Islands           800000.0         1.500000e-05
# 40                Cyprus          1300000.0         1.230769e-05
# 130            Singapore          5800000.0         6.896552e-07
# 42              Djibouti          1100000.0         1.363636e-05
#
#      high_quality_articles_per_capita
# 168                               0.0
# 34                                0.0
# 80                                0.0
# 140                               0.0
# 37                                0.0
# 139                               0.0
# 133                               0.0
# 40                                0.0
# 130                               0.0
# 42                                0.0

# %%
filtered_regional_aggregates = regional_aggregates.dropna(subset=["region"]).query("region != ''")

# %%
# Regions ranked by total articles per capita
regions_by_coverage = filtered_regional_aggregates.sort_values("articles_per_capita", ascending=False)
regions_by_coverage
# Out:
#                              region  total_articles  total_population  \
# 97                           Monaco              10      0.000000e+00
# 155                          Tuvalu               1      0.000000e+00
# 5               Antigua and Barbuda              33      1.000000e+05
# 52   Federated States of Micronesia              14      1.000000e+05
# 94                 Marshall Islands              13      1.000000e+05
# ..                              ...             ...               ...
# 165                          Zambia               3      2.020000e+07
# 123                    Saudi Arabia               5      3.690000e+07
# 58                            Ghana               4      3.410000e+07
# 67                            India             151      1.428600e+09
# 32                            China              16      1.411300e+09
#
#      high_quality_articles  articles_per_capita  \
# 97                     0.0                  inf
# 155                    0.0                  inf
# 5                      0.0         3.300000e-04
# 52                     0.0         1.400000e-04
# 94                     0.0         1.300000e-04
# ..                     ...                  ...
# 165                    0.0         1.485149e-07
# 123                    2.0         1.355014e-07
# 58                     1.0         1.173021e-07
# 67                     0.0         1.056979e-07
# 32                     0.0         1.133707e-08
#
#      high_quality_articles_per_capita
# 97                                NaN
# 155                               NaN
# 5                        0.000000e+00
# 52                       0.000000e+00
# 94                       0.000000e+00
# ..                                ...
# 165                      0.000000e+00
# 123                      5.420054e-08
# 58                       2.932551e-08
# 67                       0.000000e+00
# 32                       0.000000e+00
#
# [166 rows x 6 columns]

# %%
# Regions ranked by high-quality articles per capita
regions_by_high_quality = filtered_regional_aggregates.sort_values("high_quality_articles_per_capita", ascending=False)
regions_by_high_quality
# Out:
#          region  total_articles  total_population  high_quality_articles  \
# 99   Montenegro              36          600000.0                    3.0
# 87   Luxembourg              27          700000.0                    2.0
# 2       Albania              70         2700000.0                    7.0
# 77       Kosovo              26         1700000.0                    4.0
# 91     Maldives              33          600000.0                    1.0
# ..          ...             ...               ...                    ...
# 65     Honduras              17         9700000.0                    0.0
# 64        Haiti              34        11600000.0                    0.0
# 166    Zimbabwe              69        16700000.0                    0.0
# 97       Monaco              10               0.0                    0.0
# 155      Tuvalu               1               0.0                    0.0
#
#      articles_per_capita  high_quality_articles_per_capita
# 99              0.000060                          0.000005
# 87              0.000039                          0.000003
# 2               0.000026                          0.000003
# 77              0.000015                          0.000002
# 91              0.000055                          0.000002
# ..                   ...                               ...
# 65              0.000002                          0.000000
# 64              0.000003                          0.000000
# 166             0.000004                          0.000000
# 97                   inf                               NaN
# 155                  inf                               NaN
#
# [166 rows x 6 columns]
